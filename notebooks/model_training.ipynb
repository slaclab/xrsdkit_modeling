# %% [markdown]
# ### imports:
#     - os - for building file paths
#     - yaml - for file i/o
#     - xrsdkit.models.train - for training models
#     - xrsdkit.tools.ymltools - for saving the output file

# %%
import os

import yaml
from xrsdkit.models import train as xrsdtrain
from xrsdkit.tools import ymltools as xrsdyml

# a message callback is used to print information about model training.
# assign msg_callback to None or print, depending on desired verbosity.
msg_callback = None
#msg_callback = print

# %% [markdown]
# ### read datasets:
#
# This example uses two datasets, combined, to train the models.
# xrsdyml.read_local_dataset opens all of the files in the dataset
# and loads the relevant data into a pandas.DataFrame table.

# %%
batch_dataset_dir = os.path.join('..','batch_pd_nanoparticles','dataset')
flow_dataset_dir = os.path.join('..','flowreactor_pd_nanoparticles','dataset')

dataset, dataset_index = xrsdyml.read_local_dataset(
    [batch_dataset_dir,flow_dataset_dir],message_callback=msg_callback)
dataset
# Out:
#       experiment_id                 sample_id    noise_model  \
# 0       RxnA_201602    RxnA_201602_1455304815           flat
# 1       RxnA_201602    RxnA_201602_1455307289  low_q_scatter
# 2       RxnA_201602    RxnA_201602_1455308244  low_q_scatter
# 3       RxnA_201602    RxnA_201602_1455308448  low_q_scatter
# 4       RxnA_201602    RxnA_201602_1455306181           flat
# 5       RxnA_201602    RxnA_201602_1455306807  low_q_scatter
# 6       RxnA_201602    RxnA_201602_1455307532  low_q_scatter
# 7       RxnA_201602    RxnA_201602_1455306206           flat
# 8       RxnA_201602    RxnA_201602_1455304606           flat
# 9       RxnA_201602    RxnA_201602_1455305991           flat
# 10      RxnA_201602    RxnA_201602_1455308721  low_q_scatter
# 11      RxnA_201602    RxnA_201602_1455306155           flat
# 12      RxnA_201602    RxnA_201602_1455304851           flat
# 13      RxnA_201602    RxnA_201602_1455306373           flat
# 14      RxnA_201602    RxnA_201602_1455307358  low_q_scatter
# 15      RxnA_201602    RxnA_201602_1455306356           flat
# 16      RxnA_201602    RxnA_201602_1455307884  low_q_scatter
# 17      RxnA_201602    RxnA_201602_1455303431           flat
# 18      RxnA_201602    RxnA_201602_1455304642           flat
# 19      RxnA_201602    RxnA_201602_1455303325           flat
# 20      RxnA_201602    RxnA_201602_1455306611           flat
# 21      RxnA_201602    RxnA_201602_1455306049           flat
# 22      RxnA_201602    RxnA_201602_1455305444           flat
# 23      RxnA_201602    RxnA_201602_1455306273           flat
# 24      RxnA_201602    RxnA_201602_1455307829  low_q_scatter
# 25      RxnA_201602    RxnA_201602_1455308275  low_q_scatter
# 26      RxnA_201602    RxnA_201602_1455306471           flat
# 27      RxnA_201602    RxnA_201602_1455306759  low_q_scatter
# 28      RxnA_201602    RxnA_201602_1455305428           flat
# 29      RxnA_201602    RxnA_201602_1455305191           flat
# ...             ...                       ...            ...
# 1981  RxnA_20190329  RxnA_20190329_1553975313           flat
# 1982  RxnA_20190329  RxnA_20190329_1553920203           flat
# 1983  RxnA_20190329  RxnA_20190329_1553914977           flat
# 1984  RxnA_20190329  RxnA_20190329_1553970200           flat
# 1985  RxnA_20190329  RxnA_20190329_1553935658           flat
# 1986  RxnA_20190329  RxnA_20190329_1553980333           flat
# 1987    R5_20190417    R5_20190417_1555972808           flat
# 1988    R5_20190417    R5_20190417_1555880344           flat
# 1989    R5_20190417    R5_20190417_1556030524           flat
# 1990    R5_20190417    R5_20190417_1555968926           flat
# 1991    R5_20190417    R5_20190417_1555978190           flat
# 1992    R5_20190417    R5_20190417_1555983613           flat
# 1993    R5_20190417    R5_20190417_1555989107           flat
# 1994    R5_20190417    R5_20190417_1555878455           flat
# 1995    R5_20190417    R5_20190417_1555876280           flat
# 1996    R5_20190417    R5_20190417_1555882718           flat
# 1997    R5_20190417    R5_20190417_1555994774           flat
# 1998    RxnC_201903    RxnC_201903_1552295039           flat
# 1999    RxnC_201903    RxnC_201903_1552286907           flat
# 2000    RxnC_201903    RxnC_201903_1552257734           flat
# 2001    RxnC_201903    RxnC_201903_1552268627           flat
# 2002    RxnC_201903    RxnC_201903_1552276212           flat
# 2003    RxnC_201903    RxnC_201903_1552304459           flat
# 2004    RxnC_201903    RxnC_201903_1552314320           flat
# 2005    RxnC_201903    RxnC_201903_1552322747           flat
# 2006    RxnC_201903    RxnC_201903_1552324675           flat
# 2007    RxnC_201903    RxnC_201903_1552306412           flat
# 2008    RxnC_201903    RxnC_201903_1552278298           flat
# 2009    RxnC_201903    RxnC_201903_1552285279           flat
# 2010    RxnC_201903    RxnC_201903_1552266975           flat
#
#      pop0_distribution      pop0_form pop0_interaction pop0_lattice  \
# 0                 None  guinier_porod             None         None
# 1               single      spherical             None      F_cubic
# 2               single      spherical             None      F_cubic
# 3               single      spherical             None      F_cubic
# 4                 None  guinier_porod             None         None
# 5               single      spherical             None      F_cubic
# 6               single      spherical             None      F_cubic
# 7                 None  guinier_porod             None         None
# 8                 None  guinier_porod             None         None
# 9                 None  guinier_porod             None         None
# 10              single      spherical             None      F_cubic
# 11                None  guinier_porod             None         None
# 12                None  guinier_porod             None         None
# 13                None  guinier_porod             None         None
# 14              single      spherical             None      F_cubic
# 15                None  guinier_porod             None         None
# 16              single      spherical             None      F_cubic
# 17                None  guinier_porod             None         None
# 18                None  guinier_porod             None         None
# 19                None  guinier_porod             None         None
# 20                None  guinier_porod             None         None
# 21                None  guinier_porod             None         None
# 22                None  guinier_porod             None         None
# 23                None  guinier_porod             None         None
# 24              single      spherical             None      F_cubic
# 25              single      spherical             None      F_cubic
# 26                None  guinier_porod             None         None
# 27              single      spherical             None      F_cubic
# 28                None  guinier_porod             None         None
# 29                None  guinier_porod             None         None
# ...                ...            ...              ...          ...
# 1981              None           None             None         None
# 1982              None  guinier_porod             None         None
# 1983              None           None             None         None
# 1984              None  guinier_porod             None         None
# 1985              None  guinier_porod             None         None
# 1986              None  guinier_porod             None         None
# 1987              None  guinier_porod             None         None
# 1988              None  guinier_porod             None         None
# 1989              None           None             None         None
# 1990              None  guinier_porod             None         None
# 1991              None  guinier_porod             None         None
# 1992          r_normal      spherical             None         None
# 1993              None  guinier_porod             None         None
# 1994              None  guinier_porod             None         None
# 1995              None  guinier_porod             None         None
# 1996              None  guinier_porod             None         None
# 1997              None  guinier_porod             None         None
# 1998              None  guinier_porod             None         None
# 1999              None           None             None         None
# 2000              None  guinier_porod             None         None
# 2001              None  guinier_porod             None         None
# 2002              None  guinier_porod             None         None
# 2003              None  guinier_porod             None         None
# 2004              None  guinier_porod             None         None
# 2005              None  guinier_porod             None         None
# 2006              None  guinier_porod             None         None
# 2007          r_normal      spherical             None         None
# 2008              None  guinier_porod             None         None
# 2009              None  guinier_porod             None         None
# 2010              None  guinier_porod             None         None
#
#      pop1_distribution  pop1_form pop1_interaction  ... pearson_expq  \
# 0                 None       None             None  ...    -0.755270
# 1                 None       None             None  ...    -0.248760
# 2                 None       None             None  ...    -0.242065
# 3                 None       None             None  ...    -0.243288
# 4                 None       None             None  ...    -0.557588
# 5                 None       None             None  ...    -0.249071
# 6                 None       None             None  ...    -0.253328
# 7                 None       None             None  ...    -0.560888
# 8                 None       None             None  ...    -0.758761
# 9                 None       None             None  ...    -0.707013
# 10                None       None             None  ...    -0.250122
# 11                None       None             None  ...    -0.540061
# 12                None       None             None  ...    -0.754444
# 13            r_normal  spherical             None  ...    -0.643200
# 14                None       None             None  ...    -0.250950
# 15            r_normal  spherical             None  ...    -0.686571
# 16                None       None             None  ...    -0.260041
# 17                None       None             None  ...    -0.857313
# 18                None       None             None  ...    -0.757417
# 19                None       None             None  ...    -0.886841
# 20            r_normal  spherical             None  ...    -0.280712
# 21                None       None             None  ...    -0.664380
# 22                None       None             None  ...    -0.805832
# 23                None       None             None  ...    -0.580068
# 24                None       None             None  ...    -0.260117
# 25                None       None             None  ...    -0.242903
# 26            r_normal  spherical             None  ...    -0.556245
# 27                None       None             None  ...    -0.251964
# 28                None       None             None  ...    -0.778897
# 29                None       None             None  ...    -0.742585
# ...                ...        ...              ...  ...          ...
# 1981              None       None             None  ...     0.549115
# 1982          r_normal  spherical             None  ...    -0.578519
# 1983              None       None             None  ...     0.292591
# 1984          r_normal  spherical             None  ...    -0.515501
# 1985              None       None             None  ...    -0.419534
# 1986          r_normal  spherical             None  ...    -0.567529
# 1987          r_normal  spherical             None  ...    -0.512082
# 1988              None       None             None  ...    -0.600075
# 1989              None       None             None  ...     0.081785
# 1990          r_normal  spherical             None  ...    -0.523025
# 1991          r_normal  spherical             None  ...    -0.521115
# 1992              None       None             None  ...    -0.549482
# 1993          r_normal  spherical             None  ...    -0.502057
# 1994          r_normal  spherical             None  ...    -0.387867
# 1995          r_normal  spherical             None  ...    -0.401628
# 1996          r_normal  spherical             None  ...    -0.591890
# 1997              None       None             None  ...    -0.325629
# 1998          r_normal  spherical             None  ...    -0.681812
# 1999              None       None             None  ...     0.030706
# 2000          r_normal  spherical             None  ...    -0.737549
# 2001              None       None             None  ...    -0.424848
# 2002          r_normal  spherical             None  ...    -0.626821
# 2003          r_normal  spherical             None  ...    -0.657427
# 2004          r_normal  spherical             None  ...    -0.602088
# 2005              None       None             None  ...    -0.808628
# 2006          r_normal  spherical             None  ...    -0.665604
# 2007              None       None             None  ...    -0.523259
# 2008          r_normal  spherical             None  ...    -0.704396
# 17                0.001377                0.015800
# 18                0.015943                0.022020
# 19                0.001330                0.164995
# 20                0.001614                0.002867
# 21                0.000976                0.004388
# 22                0.000924                0.015683
# 23                0.001002                0.004071
# 24                0.001525                0.025632
# 25                0.001358                0.013536
# 26                0.002826                0.010232
# 27                0.001491                0.805672
# 28                0.001060                0.052166
# 29                0.000890                0.098037
# ...                    ...                     ...
# 1981              0.000159                0.000159
# 1982              0.001211                0.002580
# 1983              0.000268                0.000227
# 1984              0.084457                0.011708
# 1985              0.000882                0.001685
# 1986              0.007996                0.004743
# 1987              0.070718                0.006301
# 1988              0.000137                0.000128
# 1989              0.000594                0.000147
# 1990              0.039528                0.005276
# 1991              0.054215                0.006687
# 1992              0.050478                0.008305
# 1993              0.069076                0.006062
# 1994              0.001726                0.003025
# 1995              0.001300                0.003539
# 1996              0.018882                0.008619
# 1997              0.000440                0.000693
# 1998              0.114689                0.002344
# 1999              0.000057                0.000057
# 2000              0.003812                0.011044
# 2001              0.000330                0.001195
# 2002              0.297270                0.689191
# 2003              0.040881                0.013988
# 2004              0.060967                0.002702
# 2005              0.003630                0.003463
# 2006              0.070210                0.014291
# 2007              0.046231                0.011258
# 2008              0.007072                0.000515
# 2009              0.357088                0.018654
# 2010              0.004147                0.008527
#
# [2011 rows x 73 columns]

# %% [markdown]
# ### train models:
#
# Using the dataset table built in the previous step,
# a set of models is trained
# to automate the analysis
# of samples that are similar to the training set.
# Usually, feature selection and hyperparameter optimization
# are beneficial to model performance,
# but they take time, so they are turned off.
#
# At the end of the training,
# the output_dir will be populated with two new directories,
# 'classifiers' and 'regressors'.
# Each of these directory trees contains a hierarchy of models.
# Each trained model produces three files:
#
# * model_name.txt - Human-readable report of training results.
# * model_name.pickle - Machine-readable model, created by scikit-learn, for re-loading the model later without re-training.
# * model_name.yml - Human- or Machine-readable data file containing training results, model parameters, selected features, and trained hyperparameters.

# %%
model_output_dir = os.path.join('..','tutorial_models')
regressors,classifiers = xrsdtrain.train_from_dataframe(dataset,
                                                         train_hyperparameters=False,
                                                         select_features=False,
                                                         output_dir=model_output_dir,
                                                         message_callback=msg_callback
                                                        )
# Out:
# /home/lenson/.virtualenvs/xrsdkit/lib/python3.5/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/lenson/.virtualenvs/xrsdkit/lib/python3.5/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### inspect the training summary:
#
# If one or more models are to be optimized,
# the performance metrics for the latest training run
# can be found in the overall training summary,
# or in the model's own training summaries.

# %%
training_summary_file = os.path.join(model_output_dir,'training_summary.yml')
summary = yaml.load(open(training_summary_file,'r'))
#summary

# %% [markdown]
# ### add feature selection and hyperparameter training
#
# Model performance can be improved by selecting input features and tuning hyperparameters.
# Feature selection is performed by a recursive leave-one-feature-out process,
# and hyperparameter training is performed by grid search.
# In both cases, the cross-validation of the model's training metric
# is used as an objective function.

# %%
# TODO

# %% [markdown]
# ### tune the model configuration:
#
# The model configuration file can be edited to select modeling algorithms,
# choose a target performance metrics,
# and (TODO) tune cross-validation and hyperparameter selection processes.

# %%
model_config_file = os.path.join(model_output_dir,'model_config.yml')
config = yaml.load(open(model_config_file,'r'))
#config
